# %% [markdown]
# #ATM assignment No:3  2019 _4_10
# Amount
#
# Welcome to Virtual Bank
# Press 1 for Withdraw Amount
# Press 2 for Amount Deposite
# Press 3 for Balance Inquiry
# Press 4 Exit
#
# command
# #print("----------------------------------------------------------------------------------------")
#
# command
#
# Withdraw  "Please Enter the amount to withdraw: "
#
# Amount   Withdraw:
# You do not have sufficient Amount to Withdraw!")
# Please deposite amount first.")
# Do you want to Deposite amount?")
#       ("Type 1 for Yes")        ("Type 2 for No")
#
#
#     Amount "Please Enter the amount to Deposite: "
#             Congratulation your Transaction has been completed succcufully"
#            Thank you for banking with us"
#         else:
#             Thank you for banking with us
#
#
#        Congratulation your Transaction has been completed succcufully
#         Remainging_Balance = Amount - Withdraw
#    Withdraw Amount: ", Withdraw)
#       Balance        : ", Remainging_Balance
#      Please count your cash before leaving ATM
#       Thank you for banking with us
#
# elif command
#     Deposite "Please Enter the amount to Deposite: "
#     print("----------------------------------------------------------------------------------------")
#     Current_Amount  Amount  Deposite
#    "Congratulation your Transaction has been completed succcufully"
#   "Your current amount :"
#     " Thank you for banking with us"
#
# elif command
#     "Your current amount :"
#     "Thank you for banking with us"
#
# elif command
#     print
# else:
#     print("----------------------------------------------------------------------------------------")
#     print("You enter wrong amount....")
#     print("Try it Again....")
#     print("----------------------------------------------------------------------------------------")

# %%
#ATM System Made in Python Language

balance = 0
print(" Welcome to Virtual bank\n")
print("Press 1 for withdraw Amount\n")                                         #The Valus to  Diplay for Users
print("Press 2 for Amount deposit\n") 
print("Press 3 for Balance inquiry \n")
print("Press 4 For Exit")
option = int(input("What would you like to Choose: "))                          # The valuse to get from user
if option == 1:                                                               # Condition for the valuse which user entered
    balance = int(input("Please Enter the Amount to withdraw: "))                #Here the machain process the valuse
    print("You do not have sufficient Amount to Withdraw!")                      #Again Values to display for user
    print("Please deposite amount first.")
    print("Do you want to Deposite amount?")

    deposit = int(input("Type 1 For Yes " "\n""Type 2 For No: "))                #Again condition for user to select one 
    if deposit == 1:
        print("Please Enter The Amount to deposit: ")
    deposit = int(input(balance))
    raimainig_balance = balance - deposit
    print("Congratulation your Transaction has been completed succcufully")
    print("Thank you for banking with us ")
elif option == 2:                                                                # The Second Condition   
    deposit = int(input("Please Enter The Amount To Deposit: "))
    balance = balance + deposit
    print("Congratulation your Transaction has been completed succcufully")
    print("Your Current Amount is ",deposit)

elif option == 3:                                                                #Here the Thired Condition 
    print("Your Current Amount is",balance)
    print("Thank You for banking with us ")
elif option == 4:                                                               #Here The fourth condition 
    print("Please Wait for your Card to Returned \n")
    print("Thanks for banking with us")
else:
    print("----------------------------------------------------------------")   # In The last for long selection in program
    print("You Enter Wrong Amount...... ")
    print("Try It Again")
    print("----------------------------------------------------------------")
# Out:
#  Welcome to Virtual bank
#
# Press 1 for withdraw Amount
#
# Press 2 for Amount deposit
#
# Press 3 for Balance inquiry
#
# Press 4 For Exit
# What would you like to Choose: 5
# ----------------------------------------------------------------
# You Enter Wrong Amount......
# Try It Again
# ----------------------------------------------------------------
